# %% [markdown]
# <a href="https://colab.research.google.com/github/carliol89/ICTP-2018/blob/master/Copia_de_Proyecto_Pyhon_Carlos_Castillo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #Pandas es un paquete para estructuras de datos y análisis de datos.
import numpy as np #numpy es un paquete para matrices.
# !pip install folium geopandas numpy
import folium #Folium es una librería para mapas.
from folium import plugins #Módulo de complementos de Folium.
from google.colab import files
import matplotlib.pyplot as plt #Módulo de Matplotlib para realizar gráficos. Matplotlib es una biblioteca para visualizaciones estáticas, dinámicas e interactivas.
import seaborn as sns #Biblioteca basada en Matplotlib para gráfico de datos.
sns.set() # Set the styles to Seaborn
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.5)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)

# %%
#Esto es para acceder a los archivos de drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None
#path='/content/drive/MyDrive/Curso Introducción a Python, aplicado a ciencias ambientales/Proyecto/data_proyecto.xlsx'
path='/content/drive/MyDrive/data_proyecto.xlsx'

#dat_raw= pd.read_csv(path)
data_raw=pd.read_excel(path)

data=data_raw.copy()
data
#print(data)
# Out:
#     Región de muestreo  Área de muestreo  Sitio de muestreo       Fecha  \
# 0            Margarita       La Restinga                  1  2018-01-15
# 1            Margarita       La Restinga                  2  2018-01-15
# 2            Margarita       La Restinga                  3  2018-01-15
# 3            Margarita     Playa el agua                  1  2018-01-15
# 4            Margarita     Playa el agua                  2  2018-01-15
# 5            Margarita     Playa el agua                  3  2018-01-15
# 6            Margarita          Porlamar                  1  2018-01-15
# 7            Margarita          Porlamar                  2  2018-01-15
# 8            Margarita          Porlamar                  3  2018-01-15
# 9            Margarita      Punta Arenas                  1  2018-01-15
# 10           Margarita      Punta Arenas                  2  2018-01-15
# 11           Margarita      Punta Arenas                  3  2018-01-15
# 12           Margarita  Punta de piedras                  1  2018-01-15
# 13           Margarita  Punta de piedras                  2  2018-01-15
# 14           Margarita  Punta de piedras                  3  2018-01-15
# 15           Margarita       La Restinga                  1  2018-04-15
# 16           Margarita       La Restinga                  2  2018-04-15
# 17           Margarita       La Restinga                  3  2018-04-15
# 18           Margarita     Playa el agua                  1  2018-04-15
# 19           Margarita     Playa el agua                  2  2018-04-15
# 20           Margarita     Playa el agua                  3  2018-04-15
# 21           Margarita          Porlamar                  1  2018-04-15
# 22           Margarita          Porlamar                  2  2018-04-15
# 23           Margarita          Porlamar                  3  2018-04-15
# 24           Margarita      Punta Arenas                  1  2018-04-15
# 25           Margarita      Punta Arenas                  2  2018-04-15
# 26           Margarita      Punta Arenas                  3  2018-04-15
# 27           Margarita  Punta de piedras                  1  2018-04-15
# 28           Margarita  Punta de piedras                  2  2018-04-15
# 29           Margarita  Punta de piedras                  3  2018-04-15
# 30           Margarita       La Restinga                  1  2018-07-15
# 31           Margarita       La Restinga                  2  2018-07-15
# 32           Margarita       La Restinga                  3  2018-07-15
# 33           Margarita     Playa el agua                  1  2018-07-15
# 34           Margarita     Playa el agua                  2  2018-07-15
# 35           Margarita     Playa el agua                  3  2018-07-15
# 36           Margarita          Porlamar                  1  2018-07-15
# 37           Margarita          Porlamar                  2  2018-07-15
# 38           Margarita          Porlamar                  3  2018-07-15
# 39           Margarita      Punta Arenas                  1  2018-07-15
# 40           Margarita      Punta Arenas                  2  2018-07-15
# 41           Margarita      Punta Arenas                  3  2018-07-15
# 42           Margarita  Punta de piedras                  1  2018-07-15
# 43           Margarita  Punta de piedras                  2  2018-07-15
# 44           Margarita  Punta de piedras                  3  2018-07-15
# 45           Margarita       La Restinga                  1  2018-10-15
# 46           Margarita       La Restinga                  2  2018-10-15
# 47           Margarita       La Restinga                  3  2018-10-15
# 48           Margarita     Playa el agua                  1  2018-10-15
# 49           Margarita     Playa el agua                  2  2018-10-15
# 50           Margarita     Playa el agua                  3  2018-10-15
# 51           Margarita          Porlamar                  1  2018-10-15
# 52           Margarita          Porlamar                  2  2018-10-15
# 53           Margarita          Porlamar                  3  2018-10-15
# 54           Margarita      Punta Arenas                  1  2018-10-15
# 55           Margarita      Punta Arenas                  2  2018-10-15
# 56           Margarita      Punta Arenas                  3  2018-10-15
# 57           Margarita  Punta de piedras                  1  2018-10-15
# 58           Margarita  Punta de piedras                  2  2018-10-15
# 59           Margarita  Punta de piedras                  3  2018-10-15
# 60           Margarita       La Restinga                  1  2019-01-15
# 61           Margarita       La Restinga                  2  2019-01-15
# 62           Margarita       La Restinga                  3  2019-01-15
# 63           Margarita     Playa el agua                  1  2019-01-15
# 64           Margarita     Playa el agua                  2  2019-01-15
# 65           Margarita     Playa el agua                  3  2019-01-15
# 66           Margarita          Porlamar                  1  2019-01-15
# 67           Margarita          Porlamar                  2  2019-01-15
# 68           Margarita          Porlamar                  3  2019-01-15
# 69           Margarita      Punta Arenas                  1  2019-01-15
# 70           Margarita      Punta Arenas                  2  2019-01-15
# 71           Margarita      Punta Arenas                  3  2019-01-15
# 72           Margarita  Punta de piedras                  1  2019-01-15
# 73           Margarita  Punta de piedras                  2  2019-01-15
# 74           Margarita  Punta de piedras                  3  2019-01-15
# 75           Margarita       La Restinga                  1  2019-04-15
# 76           Margarita       La Restinga                  2  2019-04-15
# 77           Margarita       La Restinga                  3  2019-04-15
# 78           Margarita     Playa el agua                  1  2019-04-15
# 79           Margarita     Playa el agua                  2  2019-04-15
# 80           Margarita     Playa el agua                  3  2019-04-15
# 81           Margarita          Porlamar                  1  2019-04-15
# 82           Margarita          Porlamar                  2  2019-04-15
# 83           Margarita          Porlamar                  3  2019-04-15
# 84           Margarita      Punta Arenas                  1  2019-04-15
# 85           Margarita      Punta Arenas                  2  2019-04-15
# 86           Margarita      Punta Arenas                  3  2019-04-15
# 87           Margarita  Punta de piedras                  1  2019-04-15
# 88           Margarita  Punta de piedras                  2  2019-04-15
# 89           Margarita  Punta de piedras                  3  2019-04-15
# 90           Margarita       La Restinga                  1  2019-07-15
# 91           Margarita       La Restinga                  2  2019-07-15
# 92           Margarita       La Restinga                  3  2019-07-15
# 93           Margarita     Playa el agua                  1  2019-07-15
# 94           Margarita     Playa el agua                  2  2019-07-15
# 95           Margarita     Playa el agua                  3  2019-07-15
# 96           Margarita          Porlamar                  1  2019-07-15
# 97           Margarita          Porlamar                  2  2019-07-15
# 98           Margarita          Porlamar                  3  2019-07-15
# 99           Margarita      Punta Arenas                  1  2019-07-15
# 100          Margarita      Punta Arenas                  2  2019-07-15
# 101          Margarita      Punta Arenas                  3  2019-07-15
# 102          Margarita  Punta de piedras                  1  2019-07-15
# 103          Margarita  Punta de piedras                  2  2019-07-15
# 104          Margarita  Punta de piedras                  3  2019-07-15
# 105          Margarita       La Restinga                  1  2019-10-15
# 106          Margarita       La Restinga                  2  2019-10-15
# 107          Margarita       La Restinga                  3  2019-10-15
# 108          Margarita     Playa el agua                  1  2019-10-15
# 109          Margarita     Playa el agua                  2  2019-10-15
# 110          Margarita     Playa el agua                  3  2019-10-15
# 111          Margarita          Porlamar                  1  2019-10-15
# 112          Margarita          Porlamar                  2  2019-10-15
# 113          Margarita          Porlamar                  3  2019-10-15
# 114          Margarita      Punta Arenas                  1  2019-10-15
# 115          Margarita      Punta Arenas                  2  2019-10-15
# 116          Margarita      Punta Arenas                  3  2019-10-15
# 117          Margarita  Punta de piedras                  1  2019-10-15
# 118          Margarita  Punta de piedras                  2  2019-10-15
# 119          Margarita  Punta de piedras                  3  2019-10-15
# 120          Margarita       La Restinga                  1  2020-01-15
# 121          Margarita       La Restinga                  2  2020-01-15
# 122          Margarita       La Restinga                  3  2020-01-15
# 123          Margarita     Playa el agua                  1  2020-01-15
# 124          Margarita     Playa el agua                  2  2020-01-15
# 125          Margarita     Playa el agua                  3  2020-01-15
# 126          Margarita          Porlamar                  1  2020-01-15
# 127          Margarita          Porlamar                  2  2020-01-15
# 128          Margarita          Porlamar                  3  2020-01-15
# 129          Margarita      Punta Arenas                  1  2020-01-15
# 130          Margarita      Punta Arenas                  2  2020-01-15
# 131          Margarita      Punta Arenas                  3  2020-01-15
# 132          Margarita  Punta de piedras                  1  2020-01-15
# 133          Margarita  Punta de piedras                  2  2020-01-15
# 134          Margarita  Punta de piedras                  3  2020-01-15
# 135          Margarita       La Restinga                  1  2020-04-15
# 136          Margarita       La Restinga                  2  2020-04-15
# 137          Margarita       La Restinga                  3  2020-04-15
# 138          Margarita     Playa el agua                  1  2020-04-15
# 139          Margarita     Playa el agua                  2  2020-04-15
# 140          Margarita     Playa el agua                  3  2020-04-15
# 141          Margarita          Porlamar                  1  2020-04-15
# 142          Margarita          Porlamar                  2  2020-04-15
# 143          Margarita          Porlamar                  3  2020-04-15
# 144          Margarita      Punta Arenas                  1  2020-04-15
# 145          Margarita      Punta Arenas                  2  2020-04-15
# 146          Margarita      Punta Arenas                  3  2020-04-15
# 147          Margarita  Punta de piedras                  1  2020-04-15
# 148          Margarita  Punta de piedras                  2  2020-04-15
# 149          Margarita  Punta de piedras                  3  2020-04-15
# 150          Margarita       La Restinga                  1  2020-07-15
# 151          Margarita       La Restinga                  2  2020-07-15
# 152          Margarita       La Restinga                  3  2020-07-15
# 153          Margarita     Playa el agua                  1  2020-07-15
# 154          Margarita     Playa el agua                  2  2020-07-15
# 155          Margarita     Playa el agua                  3  2020-07-15
# 156          Margarita          Porlamar                  1  2020-07-15
# 157          Margarita          Porlamar                  2  2020-07-15
# 158          Margarita          Porlamar                  3  2020-07-15
# 159          Margarita      Punta Arenas                  1  2020-07-15
# 160          Margarita      Punta Arenas                  2  2020-07-15
# 161          Margarita      Punta Arenas                  3  2020-07-15
# 162          Margarita  Punta de piedras                  1  2020-07-15
# 163          Margarita  Punta de piedras                  2  2020-07-15
# 164          Margarita  Punta de piedras                  3  2020-07-15
# 165          Margarita       La Restinga                  1  2020-10-15
# 166          Margarita       La Restinga                  2  2020-10-15
# 167          Margarita       La Restinga                  3  2020-10-15
# 168          Margarita     Playa el agua                  1  2020-10-15
# 169          Margarita     Playa el agua                  2  2020-10-15
# 170          Margarita     Playa el agua                  3  2020-10-15
# 171          Margarita          Porlamar                  1  2020-10-15
# 172          Margarita          Porlamar                  2  2020-10-15
# 173          Margarita          Porlamar                  3  2020-10-15
# 174          Margarita      Punta Arenas                  1  2020-10-15
# 175          Margarita      Punta Arenas                  2  2020-10-15
# 176          Margarita      Punta Arenas                  3  2020-10-15
# 177          Margarita  Punta de piedras                  1  2020-10-15
# 178          Margarita  Punta de piedras                  2  2020-10-15
# 179          Margarita  Punta de piedras                  3  2020-10-15
# 180          Margarita       La Restinga                  1  2021-01-15
# 181          Margarita       La Restinga                  2  2021-01-15
# 182          Margarita       La Restinga                  3  2021-01-15
# 183          Margarita     Playa el agua                  1  2021-01-15
# 184          Margarita     Playa el agua                  2  2021-01-15
# 185          Margarita     Playa el agua                  3  2021-01-15
# 186          Margarita          Porlamar                  1  2021-01-15
# 187          Margarita          Porlamar                  2  2021-01-15
# 188          Margarita          Porlamar                  3  2021-01-15
# 189          Margarita      Punta Arenas                  1  2021-01-15
# 190          Margarita      Punta Arenas                  2  2021-01-15
# 191          Margarita      Punta Arenas                  3  2021-01-15
# 192          Margarita  Punta de piedras                  1  2021-01-15
# 193          Margarita  Punta de piedras                  2  2021-01-15
# 194          Margarita  Punta de piedras                  3  2021-01-15
# 195          Margarita       La Restinga                  1  2021-04-15
# 196          Margarita       La Restinga                  2  2021-04-15
# 197          Margarita       La Restinga                  3  2021-04-15
# 198          Margarita     Playa el agua                  1  2021-04-15
# 199          Margarita     Playa el agua                  2  2021-04-15
# 200          Margarita     Playa el agua                  3  2021-04-15
# 201          Margarita          Porlamar                  1  2021-04-15
# 202          Margarita          Porlamar                  2  2021-04-15
# 203          Margarita          Porlamar                  3  2021-04-15
# 204          Margarita      Punta Arenas                  1  2021-04-15
# 205          Margarita      Punta Arenas                  2  2021-04-15
# 206          Margarita      Punta Arenas                  3  2021-04-15
# 207          Margarita  Punta de piedras                  1  2021-04-15
# 208          Margarita  Punta de piedras                  2  2021-04-15
# 209          Margarita  Punta de piedras                  3  2021-04-15
# 210          Margarita       La Restinga                  1  2021-07-15
# 211          Margarita       La Restinga                  2  2021-07-15
# 212          Margarita       La Restinga                  3  2021-07-15
# 213          Margarita     Playa el agua                  1  2021-07-15
# 214          Margarita     Playa el agua                  2  2021-07-15
# 215          Margarita     Playa el agua                  3  2021-07-15
# 216          Margarita          Porlamar                  1  2021-07-15
# 217          Margarita          Porlamar                  2  2021-07-15
# 218          Margarita          Porlamar                  3  2021-07-15
# 219          Margarita      Punta Arenas                  1  2021-07-15
# 220          Margarita      Punta Arenas                  2  2021-07-15
# 221          Margarita      Punta Arenas                  3  2021-07-15
# 222          Margarita  Punta de piedras                  1  2021-07-15
# 223          Margarita  Punta de piedras                  2  2021-07-15
# 224          Margarita  Punta de piedras                  3  2021-07-15
# 225          Margarita       La Restinga                  1  2021-10-15
# 226          Margarita       La Restinga                  2  2021-10-15
# 227          Margarita       La Restinga                  3  2021-10-15
# 228          Margarita     Playa el agua                  1  2021-10-15
# 229          Margarita     Playa el agua                  2  2021-10-15
# 230          Margarita     Playa el agua                  3  2021-10-15
# 231          Margarita          Porlamar                  1  2021-10-15
# 232          Margarita          Porlamar                  2  2021-10-15
# 233          Margarita          Porlamar                  3  2021-10-15
# 234          Margarita      Punta Arenas                  1  2021-10-15
# 235          Margarita      Punta Arenas                  2  2021-10-15
# 236          Margarita      Punta Arenas                  3  2021-10-15
# 237          Margarita  Punta de piedras                  1  2021-10-15
# 238          Margarita  Punta de piedras                  2  2021-10-15
# 239          Margarita  Punta de piedras                  3  2021-10-15
# 240          Margarita       La Restinga                  1  2022-01-15
# 241          Margarita       La Restinga                  2  2022-01-15
# 242          Margarita       La Restinga                  3  2022-01-15
# 243          Margarita     Playa el agua                  1  2022-01-15
# 244          Margarita     Playa el agua                  2  2022-01-15
# 245          Margarita     Playa el agua                  3  2022-01-15
# 246          Margarita          Porlamar                  1  2022-01-15
# 247          Margarita          Porlamar                  2  2022-01-15
# 248          Margarita          Porlamar                  3  2022-01-15
# 249          Margarita      Punta Arenas                  1  2022-01-15
# 250          Margarita      Punta Arenas                  2  2022-01-15
# 251          Margarita      Punta Arenas                  3  2022-01-15
# 252          Margarita  Punta de piedras                  1  2022-01-15
# 253          Margarita  Punta de piedras                  2  2022-01-15
# 254          Margarita  Punta de piedras                  3  2022-01-15
# 255          Margarita       La Restinga                  1  2022-04-15
# 256          Margarita       La Restinga                  2  2022-04-15
# 257          Margarita       La Restinga                  3  2022-04-15
# 258          Margarita     Playa el agua                  1  2022-04-15
# 259          Margarita     Playa el agua                  2  2022-04-15
# 260          Margarita     Playa el agua                  3  2022-04-15
# 261          Margarita          Porlamar                  1  2022-04-15
# 262          Margarita          Porlamar                  2  2022-04-15
# 263          Margarita          Porlamar                  3  2022-04-15
# 264          Margarita      Punta Arenas                  1  2022-04-15
# 265          Margarita      Punta Arenas                  2  2022-04-15
# 266          Margarita      Punta Arenas                  3  2022-04-15
# 267          Margarita  Punta de piedras                  1  2022-04-15
# 268          Margarita  Punta de piedras                  2  2022-04-15
# 269          Margarita  Punta de piedras                  3  2022-04-15
# 270          Margarita       La Restinga                  1  2022-07-15
# 271          Margarita       La Restinga                  2  2022-07-15
# 272          Margarita       La Restinga                  3  2022-07-15
# 273          Margarita     Playa el agua                  1  2022-07-15
# 274          Margarita     Playa el agua                  2  2022-07-15
# 275          Margarita     Playa el agua                  3  2022-07-15
# 276          Margarita          Porlamar                  1  2022-07-15
# 277          Margarita          Porlamar                  2  2022-07-15
# 278          Margarita          Porlamar                  3  2022-07-15
# 279          Margarita      Punta Arenas                  1  2022-07-15
# 280          Margarita      Punta Arenas                  2  2022-07-15
# 281          Margarita      Punta Arenas                  3  2022-07-15
# 282          Margarita  Punta de piedras                  1  2022-07-15
# 283          Margarita  Punta de piedras                  2  2022-07-15
# 284          Margarita  Punta de piedras                  3  2022-07-15
# 285          Margarita       La Restinga                  1  2022-10-15
# 286          Margarita       La Restinga                  2  2022-10-15
# 287          Margarita       La Restinga                  3  2022-10-15
# 288          Margarita     Playa el agua                  1  2022-10-15
# 289          Margarita     Playa el agua                  2  2022-10-15
# 290          Margarita     Playa el agua                  3  2022-10-15
# 291          Margarita          Porlamar                  1  2022-10-15
# 292          Margarita          Porlamar                  2  2022-10-15
# 293          Margarita          Porlamar                  3  2022-10-15
# 294          Margarita      Punta Arenas                  1  2022-10-15
# 295          Margarita      Punta Arenas                  2  2022-10-15
# 296          Margarita      Punta Arenas                  3  2022-10-15
# 297          Margarita  Punta de piedras                  1  2022-10-15
# 298          Margarita  Punta de piedras                  2  2022-10-15
# 299          Margarita  Punta de piedras                  3  2022-10-15
#
#     Latitud (° ' '') Longitud (° ' '')  Temperatura (°C)        pH  \
# 0       11°1'35.15"N     64°10'53.10"W         28.843873  7.904688
# 1       11°0'52.71"N      64°9'56.76"W         28.072301  7.732033
# 2       11°0'15.78"N      64°8'53.38"W         29.593720  7.488798
# 3       11°10'7.90"N     63°52'41.97"W         25.232745  7.333610
# 4        11°9'9.73"N     63°52'11.46"W         29.559778  8.611946
# 5       11°8'23.64"N     63°51'24.68"W         29.538334  8.198418
# 6      10°56'40.96"N     63°51'43.36"W         25.346535  7.039904
# 7      10°57'11.04"N     63°50'45.08"W         29.699208  7.805991
# 8      10°57'18.98"N     63°49'39.70"W         25.553802  8.854081
# 9      10°59'19.24"N     64°23'59.75"W         29.612945  8.759371
# 10     10°58'21.07"N     64°24'29.45"W         27.170701  8.458610
# 11      10°58'7.98"N     64°23'25.79"W         27.432901  8.567989
# 12      10°54'4.29"N      64°6'30.63"W         29.837097  7.596107
# 13     10°53'50.46"N      64°5'27.66"W         27.490924  8.929639
# 14     10°53'49.87"N      64°4'23.59"W         29.487479  7.285255
# 15      11°1'35.15"N     64°10'53.10"W         29.083737  8.512104
# 16      11°0'52.71"N      64°9'56.76"W         26.282754  8.456878
# 17      11°0'15.78"N      64°8'53.38"W         26.504890  8.701335
# 18      11°10'7.90"N     63°52'41.97"W         29.154360  8.839312
# 19       11°9'9.73"N     63°52'11.46"W         25.262513  7.901414
# 20      11°8'23.64"N     63°51'24.68"W         29.701304  8.932575
# 21     10°56'40.96"N     63°51'43.36"W         28.463569  7.656607
# 22     10°57'11.04"N     63°50'45.08"W         26.342420  8.339620
# 23     10°57'18.98"N     63°49'39.70"W         25.522620  7.293260
# 24     10°59'19.24"N     64°23'59.75"W         26.435054  8.005995
# 25     10°58'21.07"N     64°24'29.45"W         29.965875  8.064906
# 26      10°58'7.98"N     64°23'25.79"W         26.564083  7.067416
# 27      10°54'4.29"N      64°6'30.63"W         28.572335  7.472537
# 28     10°53'50.46"N      64°5'27.66"W         28.981680  7.315711
# 29     10°53'49.87"N      64°4'23.59"W         29.006550  7.722867
# 30      11°1'35.15"N     64°10'53.10"W         28.169425  7.738734
# 31      11°0'52.71"N      64°9'56.76"W         26.977265  7.975208
# 32      11°0'15.78"N      64°8'53.38"W         25.626403  7.704281
# 33      11°10'7.90"N     63°52'41.97"W         29.422535  8.907752
# 34       11°9'9.73"N     63°52'11.46"W         29.101370  8.976491
# 35      11°8'23.64"N     63°51'24.68"W         26.772996  7.747782
# 36     10°56'40.96"N     63°51'43.36"W         28.197141  8.715776
# 37     10°57'11.04"N     63°50'45.08"W         25.726121  8.968807
# 38     10°57'18.98"N     63°49'39.70"W         27.557037  8.790131
# 39     10°59'19.24"N     64°23'59.75"W         28.261282  8.634550
# 40     10°58'21.07"N     64°24'29.45"W         27.664629  8.931479
# 41      10°58'7.98"N     64°23'25.79"W         26.666130  8.869061
# 42      10°54'4.29"N      64°6'30.63"W         26.145222  7.076573
# 43     10°53'50.46"N      64°5'27.66"W         29.149180  7.386645
# 44     10°53'49.87"N      64°4'23.59"W         25.654610  7.020012
# 45      11°1'35.15"N     64°10'53.10"W         26.569418  8.879925
# 46      11°0'52.71"N      64°9'56.76"W         29.752549  8.405599
# 47      11°0'15.78"N      64°8'53.38"W         28.364824  8.013246
# 48      11°10'7.90"N     63°52'41.97"W         27.937496  7.789160
# 49       11°9'9.73"N     63°52'11.46"W         26.801780  8.033029
# 50      11°8'23.64"N     63°51'24.68"W         27.066477  7.704816
# 51     10°56'40.96"N     63°51'43.36"W         26.969577  8.621947
# 52     10°57'11.04"N     63°50'45.08"W         25.586000  8.695413
# 53     10°57'18.98"N     63°49'39.70"W         25.418067  7.887028
# 54     10°59'19.24"N     64°23'59.75"W         28.933465  8.315194
# 55     10°58'21.07"N     64°24'29.45"W         28.739128  7.902457
# 56      10°58'7.98"N     64°23'25.79"W         26.369502  7.395392
# 57      10°54'4.29"N      64°6'30.63"W         25.257014  7.764012
# 58     10°53'50.46"N      64°5'27.66"W         29.075902  7.357444
# 59     10°53'49.87"N      64°4'23.59"W         25.512274  7.960562
# 60      11°1'35.15"N     64°10'53.10"W         26.546362  8.888923
# 61      11°0'52.71"N      64°9'56.76"W         25.638197  7.339842
# 62      11°0'15.78"N      64°8'53.38"W         28.279342  8.528502
# 63      11°10'7.90"N     63°52'41.97"W         25.154932  7.853803
# 64       11°9'9.73"N     63°52'11.46"W         29.680616  8.387289
# 65      11°8'23.64"N     63°51'24.68"W         28.061937  7.542547
# 66     10°56'40.96"N     63°51'43.36"W         28.532561  8.825941
# 67     10°57'11.04"N     63°50'45.08"W         29.337901  7.888775
# 68     10°57'18.98"N     63°49'39.70"W         26.110403  7.247132
# 69     10°59'19.24"N     64°23'59.75"W         29.570956  8.324766
# 70     10°58'21.07"N     64°24'29.45"W         27.022688  8.317005
# 71      10°58'7.98"N     64°23'25.79"W         26.989216  7.008582
# 72      10°54'4.29"N      64°6'30.63"W         26.708402  8.026895
# 73     10°53'50.46"N      64°5'27.66"W         29.588093  8.185277
# 74     10°53'49.87"N      64°4'23.59"W         29.491277  7.604668
# 75      11°1'35.15"N     64°10'53.10"W         29.446757  7.903551
# 76      11°0'52.71"N      64°9'56.76"W         28.483492  7.617537
# 77      11°0'15.78"N      64°8'53.38"W         26.596866  8.713845
# 78      11°10'7.90"N     63°52'41.97"W         28.560473  8.239602
# 79       11°9'9.73"N     63°52'11.46"W         25.886918  7.797793
# 80      11°8'23.64"N     63°51'24.68"W         27.767971  8.179722
# 81     10°56'40.96"N     63°51'43.36"W         28.010951  8.849775
# 82     10°57'11.04"N     63°50'45.08"W         28.178734  8.363569
# 83     10°57'18.98"N     63°49'39.70"W         27.349304  8.272539
# 84     10°59'19.24"N     64°23'59.75"W         26.081839  7.910318
# 85     10°58'21.07"N     64°24'29.45"W         26.599928  7.985476
# 86      10°58'7.98"N     64°23'25.79"W         26.319546  7.488574
# 87      10°54'4.29"N      64°6'30.63"W         25.318254  8.857988
# 88     10°53'50.46"N      64°5'27.66"W         25.687555  8.288930
# 89     10°53'49.87"N      64°4'23.59"W         25.593558  7.874951
# 90      11°1'35.15"N     64°10'53.10"W         25.305561  7.749591
# 91      11°0'52.71"N      64°9'56.76"W         28.009731  8.302285
# 92      11°0'15.78"N      64°8'53.38"W         27.717054  7.606563
# 93      11°10'7.90"N     63°52'41.97"W         27.588777  8.347231
# 94       11°9'9.73"N     63°52'11.46"W         26.263881  7.041286
# 95      11°8'23.64"N     63°51'24.68"W         29.091649  8.068148
# 96     10°56'40.96"N     63°51'43.36"W         25.881381  7.743590
# 97     10°57'11.04"N     63°50'45.08"W         27.716118  8.905842
# 98     10°57'18.98"N     63°49'39.70"W         28.113003  8.229953
# 99     10°59'19.24"N     64°23'59.75"W         26.953098  8.264492
# 100    10°58'21.07"N     64°24'29.45"W         27.581361  7.749874
# 101     10°58'7.98"N     64°23'25.79"W         29.195554  7.311360
# 102     10°54'4.29"N      64°6'30.63"W         28.970409  8.961784
# 103    10°53'50.46"N      64°5'27.66"W         26.511316  7.981840
# 104    10°53'49.87"N      64°4'23.59"W         28.707397  7.487393
# 105     11°1'35.15"N     64°10'53.10"W         26.753254  8.123359
# 106     11°0'52.71"N      64°9'56.76"W         25.666814  8.761170
# 107     11°0'15.78"N      64°8'53.38"W         28.243674  8.574540
# 108     11°10'7.90"N     63°52'41.97"W         25.068462  8.833603
# 109      11°9'9.73"N     63°52'11.46"W         28.240960  8.194790
# 110     11°8'23.64"N     63°51'24.68"W         27.496534  8.648750
# 111    10°56'40.96"N     63°51'43.36"W         29.708724  8.491434
# 112    10°57'11.04"N     63°50'45.08"W         26.204216  7.065066
# 113    10°57'18.98"N     63°49'39.70"W         27.184298  8.502214
# 114    10°59'19.24"N     64°23'59.75"W         27.248629  7.488875
# 115    10°58'21.07"N     64°24'29.45"W         27.408219  8.499138
# 116     10°58'7.98"N     64°23'25.79"W         25.179605  7.822008
# 117     10°54'4.29"N      64°6'30.63"W         29.254665  7.854643
# 118    10°53'50.46"N      64°5'27.66"W         27.858160  8.289418
# 119    10°53'49.87"N      64°4'23.59"W         25.706499  8.582538
# 120     11°1'35.15"N     64°10'53.10"W         29.318014  7.593850
# 121     11°0'52.71"N      64°9'56.76"W         25.573270  7.971520
# 122     11°0'15.78"N      64°8'53.38"W         27.234265  8.740755
# 123     11°10'7.90"N     63°52'41.97"W         25.512953  8.133056
# 124      11°9'9.73"N     63°52'11.46"W         29.279864  8.235280
# 125     11°8'23.64"N     63°51'24.68"W         29.138204  7.674589
# 126    10°56'40.96"N     63°51'43.36"W         29.833888  8.194364
# 127    10°57'11.04"N     63°50'45.08"W         29.583359  8.771509
# 128    10°57'18.98"N     63°49'39.70"W         26.001065  7.201983
# 129    10°59'19.24"N     64°23'59.75"W         25.650861  7.856232
# 130    10°58'21.07"N     64°24'29.45"W         25.310665  7.627246
# 131     10°58'7.98"N     64°23'25.79"W         27.760559  7.102458
# 132     10°54'4.29"N      64°6'30.63"W         28.911917  8.536309
# 133    10°53'50.46"N      64°5'27.66"W         27.239231  8.075115
# 134    10°53'49.87"N      64°4'23.59"W         25.599743  8.541365
# 135     11°1'35.15"N     64°10'53.10"W         25.550461  7.228763
# 136     11°0'52.71"N      64°9'56.76"W         26.436482  8.855127
# 137     11°0'15.78"N      64°8'53.38"W         27.531094  7.755752
# 138     11°10'7.90"N     63°52'41.97"W         26.002032  8.264788
# 139      11°9'9.73"N     63°52'11.46"W         29.186039  8.403346
# 140     11°8'23.64"N     63°51'24.68"W         25.939071  8.940304
# 141    10°56'40.96"N     63°51'43.36"W         25.089214  7.605794
# 142    10°57'11.04"N     63°50'45.08"W         29.013222  7.367450
# 143    10°57'18.98"N     63°49'39.70"W         25.252170  8.360194
# 144    10°59'19.24"N     64°23'59.75"W         28.987106  7.519346
# 145    10°58'21.07"N     64°24'29.45"W         28.125197  8.874248
# 146     10°58'7.98"N     64°23'25.79"W         28.419779  7.253442
# 147     10°54'4.29"N      64°6'30.63"W         26.387277  8.502776
# 148    10°53'50.46"N      64°5'27.66"W         27.640423  7.910416
# 149    10°53'49.87"N      64°4'23.59"W         26.645398  8.595815
# 150     11°1'35.15"N     64°10'53.10"W         26.973261  7.956620
# 151     11°0'52.71"N      64°9'56.76"W         26.801013  8.015089
# 152     11°0'15.78"N      64°8'53.38"W         29.919695  7.841130
# 153     11°10'7.90"N     63°52'41.97"W         27.792076  8.480331
# 154      11°9'9.73"N     63°52'11.46"W         28.115047  8.982981
# 155     11°8'23.64"N     63°51'24.68"W         27.216103  7.452986
# 156    10°56'40.96"N     63°51'43.36"W         25.087159  8.374578
# 157    10°57'11.04"N     63°50'45.08"W         25.024395  8.853542
# 158    10°57'18.98"N     63°49'39.70"W         27.414494  7.007237
# 159    10°59'19.24"N     64°23'59.75"W         29.546343  7.499788
# 160    10°58'21.07"N     64°24'29.45"W         25.997975  7.837466
# 161     10°58'7.98"N     64°23'25.79"W         29.309872  8.999610
# 162     10°54'4.29"N      64°6'30.63"W         26.420195  8.198370
# 163    10°53'50.46"N      64°5'27.66"W         29.495009  8.473306
# 164    10°53'49.87"N      64°4'23.59"W         27.135943  7.070003
# 165     11°1'35.15"N     64°10'53.10"W         28.387980  8.002107
# 166     11°0'52.71"N      64°9'56.76"W         29.829827  7.667380
# 167     11°0'15.78"N      64°8'53.38"W         26.440077  7.789213
# 168     11°10'7.90"N     63°52'41.97"W         28.395865  7.324968
# 169      11°9'9.73"N     63°52'11.46"W         26.262089  7.231171
# 170     11°8'23.64"N     63°51'24.68"W         27.960688  7.080118
# 171    10°56'40.96"N     63°51'43.36"W         28.618111  8.577211
# 172    10°57'11.04"N     63°50'45.08"W         27.452362  7.014639
# 173    10°57'18.98"N     63°49'39.70"W         25.912376  7.444438
# 174    10°59'19.24"N     64°23'59.75"W         28.423899  8.978077
# 175    10°58'21.07"N     64°24'29.45"W         27.887708  8.675911
# 176     10°58'7.98"N     64°23'25.79"W         29.843078  7.272012
# 177     10°54'4.29"N      64°6'30.63"W         27.239423  7.473213
# 178    10°53'50.46"N      64°5'27.66"W         28.146942  7.175031
# 179    10°53'49.87"N      64°4'23.59"W         28.475681  8.199167
# 180     11°1'35.15"N     64°10'53.10"W         25.443166  7.767164
# 181     11°0'52.71"N      64°9'56.76"W         25.978528  7.434225
# 182     11°0'15.78"N      64°8'53.38"W         29.369955  8.925091
# 183     11°10'7.90"N     63°52'41.97"W         26.856497  8.808511
# 184      11°9'9.73"N     63°52'11.46"W         27.972681  8.009654
# 185     11°8'23.64"N     63°51'24.68"W         25.543556  7.122270
# 186    10°56'40.96"N     63°51'43.36"W         27.280107  7.471505
# 187    10°57'11.04"N     63°50'45.08"W         28.663153  8.515639
# 188    10°57'18.98"N     63°49'39.70"W         26.123340  8.119019
# 189    10°59'19.24"N     64°23'59.75"W         25.378063  7.576765
# 190    10°58'21.07"N     64°24'29.45"W         27.913037  8.514267
# 191     10°58'7.98"N     64°23'25.79"W         26.260045  8.563931
# 192     10°54'4.29"N      64°6'30.63"W         28.926834  8.982785
# 193    10°53'50.46"N      64°5'27.66"W         25.216994  7.265244
# 194    10°53'49.87"N      64°4'23.59"W         28.070011  7.548563
# 195     11°1'35.15"N     64°10'53.10"W         29.017630  7.847252
# 196     11°0'52.71"N      64°9'56.76"W         28.383095  8.475867
# 197     11°0'15.78"N      64°8'53.38"W         27.495536  8.268622
# 198     11°10'7.90"N     63°52'41.97"W         28.543889  7.427446
# 199      11°9'9.73"N     63°52'11.46"W         25.912509  7.280639
# 200     11°8'23.64"N     63°51'24.68"W         28.485010  7.374602
# 201    10°56'40.96"N     63°51'43.36"W         25.119790  8.423293
# 202    10°57'11.04"N     63°50'45.08"W         28.192702  7.889205
# 203    10°57'18.98"N     63°49'39.70"W         25.569286  7.966736
# 204    10°59'19.24"N     64°23'59.75"W         27.210883  7.160548
# 205    10°58'21.07"N     64°24'29.45"W         29.355671  8.150989
# 206     10°58'7.98"N     64°23'25.79"W         28.361662  7.143098
# 207     10°54'4.29"N      64°6'30.63"W         25.570220  8.365888
# 208    10°53'50.46"N      64°5'27.66"W         25.046809  8.603254
# 209    10°53'49.87"N      64°4'23.59"W         29.150776  8.635926
# 210     11°1'35.15"N     64°10'53.10"W         25.962235  7.816548
# 211     11°0'52.71"N      64°9'56.76"W         26.234057  8.881716
# 212     11°0'15.78"N      64°8'53.38"W         25.825685  8.823621
# 213     11°10'7.90"N     63°52'41.97"W         28.344299  8.373359
# 214      11°9'9.73"N     63°52'11.46"W         29.797200  8.751169
# 215     11°8'23.64"N     63°51'24.68"W         27.433802  7.869317
# 216    10°56'40.96"N     63°51'43.36"W         26.549381  7.329876
# 217    10°57'11.04"N     63°50'45.08"W         25.305248  7.395969
# 218    10°57'18.98"N     63°49'39.70"W         28.942432  7.254771
# 219    10°59'19.24"N     64°23'59.75"W         27.648389  8.220709
# 220    10°58'21.07"N     64°24'29.45"W         27.855188  7.802179
# 221     10°58'7.98"N     64°23'25.79"W         27.658214  7.257567
# 222     10°54'4.29"N      64°6'30.63"W         29.400926  7.063365
# 223    10°53'50.46"N      64°5'27.66"W         29.683241  7.298528
# 224    10°53'49.87"N      64°4'23.59"W         25.163632  8.121749
# 225     11°1'35.15"N     64°10'53.10"W         26.506399  8.171554
# 226     11°0'52.71"N      64°9'56.76"W         27.514013  8.616296
# 227     11°0'15.78"N      64°8'53.38"W         26.340198  8.659039
# 228     11°10'7.90"N     63°52'41.97"W         27.559805  8.990015
# 229      11°9'9.73"N     63°52'11.46"W         25.062924  7.529231
# 230     11°8'23.64"N     63°51'24.68"W         28.519965  7.678795
# 231    10°56'40.96"N     63°51'43.36"W         28.395238  7.305104
# 232    10°57'11.04"N     63°50'45.08"W         28.071375  7.722161
# 233    10°57'18.98"N     63°49'39.70"W         29.249214  7.053903
# 234    10°59'19.24"N     64°23'59.75"W         29.876766  8.267482
# 235    10°58'21.07"N     64°24'29.45"W         26.814622  7.259734
# 236     10°58'7.98"N     64°23'25.79"W         29.511181  8.732020
# 237     10°54'4.29"N      64°6'30.63"W         28.561194  8.348026
# 238    10°53'50.46"N      64°5'27.66"W         25.722891  8.681580
# 239    10°53'49.87"N      64°4'23.59"W         27.213036  7.647253
# 240     11°1'35.15"N     64°10'53.10"W         25.184787  8.624179
# 241     11°0'52.71"N      64°9'56.76"W         26.567575  8.905292
# 242     11°0'15.78"N      64°8'53.38"W         26.377619  8.639680
# 243     11°10'7.90"N     63°52'41.97"W         25.806720  7.619954
# 244      11°9'9.73"N     63°52'11.46"W         26.014319  7.182358
# 245     11°8'23.64"N     63°51'24.68"W         26.402405  7.008844
# 246    10°56'40.96"N     63°51'43.36"W         27.359823  8.318403
# 247    10°57'11.04"N     63°50'45.08"W         26.189625  8.030988
# 248    10°57'18.98"N     63°49'39.70"W         25.086156  7.186029
# 249    10°59'19.24"N     64°23'59.75"W         26.553324  7.501044
# 250    10°58'21.07"N     64°24'29.45"W         27.491613  7.694086
# 251     10°58'7.98"N     64°23'25.79"W         25.937224  8.210671
# 252     10°54'4.29"N      64°6'30.63"W         28.248115  8.693625
# 253    10°53'50.46"N      64°5'27.66"W         29.419416  7.477164
# 254    10°53'49.87"N      64°4'23.59"W         29.573689  8.794441
# 255     11°1'35.15"N     64°10'53.10"W         29.843577  8.471926
# 256     11°0'52.71"N      64°9'56.76"W         28.392828  7.646246
# 257     11°0'15.78"N      64°8'53.38"W         25.289488  7.245115
# 258     11°10'7.90"N     63°52'41.97"W         29.053459  7.173886
# 259      11°9'9.73"N     63°52'11.46"W         25.255781  7.982971
# 260     11°8'23.64"N     63°51'24.68"W         26.790484  8.186573
# 261    10°56'40.96"N     63°51'43.36"W         27.530672  7.886446
# 262    10°57'11.04"N     63°50'45.08"W         29.885464  8.800478
# 263    10°57'18.98"N     63°49'39.70"W         29.027093  7.507153
# 264    10°59'19.24"N     64°23'59.75"W         29.357715  8.342247
# 265    10°58'21.07"N     64°24'29.45"W         28.506769  8.300992
# 266     10°58'7.98"N     64°23'25.79"W         27.621244  8.631021
# 267     10°54'4.29"N      64°6'30.63"W         26.528228  8.371712
# 268    10°53'50.46"N      64°5'27.66"W         28.447099  7.268682
# 269    10°53'49.87"N      64°4'23.59"W         26.031383  7.469387
# 270     11°1'35.15"N     64°10'53.10"W         28.954531  7.031399
# 271     11°0'52.71"N      64°9'56.76"W         29.846481  8.885090
# 272     11°0'15.78"N      64°8'53.38"W         26.647663  8.218696
# 273     11°10'7.90"N     63°52'41.97"W         25.508059  7.485836
# 274      11°9'9.73"N     63°52'11.46"W         29.153124  7.318107
# 275     11°8'23.64"N     63°51'24.68"W         27.142967  7.186374
# 276    10°56'40.96"N     63°51'43.36"W         25.889110  7.832824
# 277    10°57'11.04"N     63°50'45.08"W         27.492592  8.471094
# 278    10°57'18.98"N     63°49'39.70"W         28.937966  8.142353
# 279    10°59'19.24"N     64°23'59.75"W         27.075016  7.905385
# 280    10°58'21.07"N     64°24'29.45"W         29.230291  8.708701
# 281     10°58'7.98"N     64°23'25.79"W         29.969349  7.572889
# 282     10°54'4.29"N      64°6'30.63"W         25.350498  7.197229
# 283    10°53'50.46"N      64°5'27.66"W         25.745160  8.122163
# 284    10°53'49.87"N      64°4'23.59"W         26.682515  7.952064
# 285     11°1'35.15"N     64°10'53.10"W         25.400722  7.851534
# 286     11°0'52.71"N      64°9'56.76"W         27.687894  8.581578
# 287     11°0'15.78"N      64°8'53.38"W         29.486621  7.698780
# 288     11°10'7.90"N     63°52'41.97"W         29.383019  7.068721
# 289      11°9'9.73"N     63°52'11.46"W         29.087937  7.206597
# 290     11°8'23.64"N     63°51'24.68"W         27.681980  8.740537
# 291    10°56'40.96"N     63°51'43.36"W         25.349397  8.639858
# 292    10°57'11.04"N     63°50'45.08"W         25.377904  8.969533
# 293    10°57'18.98"N     63°49'39.70"W         28.146431  8.292018
# 294    10°59'19.24"N     64°23'59.75"W         25.609361  8.672514
# 295    10°58'21.07"N     64°24'29.45"W         27.238273  7.028313
# 296     10°58'7.98"N     64°23'25.79"W         28.032869  7.329613
# 297     10°54'4.29"N      64°6'30.63"W         26.747367  8.049163
# 298    10°53'50.46"N      64°5'27.66"W         27.637136  7.010900
# 299    10°53'49.87"N      64°4'23.59"W         28.799810  8.177062
#
#      Salinidad (PSU)  Clorofila a (mg.m-3)
# 0          36.288056              0.799730
# 1          37.743420              0.777745
# 2          34.997775              0.745759
# 3          35.663181              0.612321
# 4          34.618873              0.580022
# 5          32.011398              0.283705
# 6          32.999190              0.756512
# 7          33.704720              0.792445
# 8          32.330109              0.365414
# 9          34.825221              0.119217
# 10         33.633532              0.860996
# 11         37.484720              0.248681
# 12         32.220962              0.737330
# 13         32.095697              0.657753
# 14         36.166139              0.414888
# 15         35.702379              0.067220
# 16         32.430953              0.624137
# 17         37.577404              0.046346
# 18         37.667789              0.956582
# 19         32.384069              0.241320
# 20         34.601225              0.779461
# 21         37.879906              0.985721
# 22         35.858161              0.326333
# 23         32.223045              0.390228
# 24         37.444503              0.030858
# 25         34.481837              0.684360
# 26         34.670117              0.977600
# 27         34.806847              0.118764
# 28         35.966962              0.734608
# 29         34.686325              0.309596
# 30         37.734405              0.530697
# 31         34.240657              0.615276
# 32         34.530475              0.590859
# 33         35.430504              0.084561
# 34         37.880521              0.911589
# 35         32.520930              0.557422
# 36         34.418515              0.864967
# 37         32.056095              0.216558
# 38         34.440464              0.240780
# 39         34.291481              0.133873
# 40         37.154206              0.220913
# 41         36.041619              0.816365
# 42         35.293349              0.301896
# 43         34.485924              0.526355
# 44         34.350832              0.029986
# 45         35.703261              0.202459
# 46         32.864306              0.873003
# 47         36.686666              0.583167
# 48         35.827990              0.395466
# 49         32.738623              0.685614
# 50         33.920375              0.182217
# 51         35.551453              0.544450
# 52         35.886568              0.861576
# 53         32.155141              0.570519
# 54         32.628016              0.280442
# 55         34.430179              0.139590
# 56         37.863379              0.073402
# 57         34.716369              0.845746
# 58         32.158702              0.554963
# 59         34.810366              0.642555
# 60         32.965354              0.320388
# 61         36.453592              0.618288
# 62         37.792160              0.152906
# 63         35.886761              0.726440
# 64         37.127077              0.125156
# 65         36.171024              0.308528
# 66         37.546400              0.674491
# 67         35.960458              0.867837
# 68         36.923905              0.279163
# 69         34.543014              0.302184
# 70         32.693282              0.704143
# 71         34.950755              0.629012
# 72         35.489199              0.093216
# 73         37.562631              0.669140
# 74         35.313011              0.918551
# 75         33.131657              0.439879
# 76         36.902933              0.099185
# 77         34.436214              0.973089
# 78         32.938225              0.610935
# 79         35.102299              0.351042
# 80         36.109758              0.238853
# 81         33.139790              0.526894
# 82         34.671991              0.572748
# 83         32.167911              0.063352
# 84         34.849397              0.652349
# 85         35.850661              0.651661
# 86         36.257539              0.899350
# 87         33.513846              0.489697
# 88         37.278508              0.684277
# 89         34.062598              0.802643
# 90         32.038278              0.510112
# 91         33.706397              0.775912
# 92         36.218475              0.810560
# 93         37.334222              0.175769
# 94         34.052537              0.023414
# 95         35.544255              0.636901
# 96         34.725918              0.843041
# 97         32.789350              0.573013
# 98         32.365505              0.624842
# 99         36.522942              0.241222
# 100        36.636645              0.111628
# 101        36.544078              0.225796
# 102        33.851695              0.902966
# 103        32.009921              0.949891
# 104        32.513859              0.263444
# 105        35.557004              0.901733
# 106        37.565285              0.697934
# 107        36.743263              0.600930
# 108        33.235273              0.818849
# 109        33.294087              0.023868
# 110        37.528143              0.317832
# 111        34.261760              0.069548
# 112        36.974380              0.824107
# 113        36.325342              0.833110
# 114        33.086211              0.370069
# 115        35.763653              0.687986
# 116        34.267713              0.275307
# 117        37.647327              0.123220
# 118        35.838883              0.445728
# 119        37.205225              0.556143
# 120        35.432578              0.396560
# 121        36.148109              0.923488
# 122        36.406492              0.094496
# 123        36.235676              0.950601
# 124        32.771625              0.796810
# 125        36.645562              0.428951
# 126        36.997631              0.371028
# 127        33.305558              0.973060
# 128        32.697469              0.789437
# 129        36.457635              0.147653
# 130        36.964333              0.645554
# 131        32.584147              0.298562
# 132        35.258950              0.765192
# 133        37.956870              0.678115
# 134        33.707100              0.661375
# 135        32.887081              0.019743
# 136        32.224058              0.170440
# 137        32.160592              0.384891
# 138        33.739456              0.259025
# 139        34.155756              0.683871
# 140        35.718394              0.825737
# 141        32.572266              0.320573
# 142        34.915085              0.308784
# 143        34.239077              0.143162
# 144        34.724081              0.553287
# 145        37.258631              0.505559
# 146        35.068530              0.303488
# 147        33.699171              0.470903
# 148        32.954593              0.534274
# 149        36.747464              0.828249
# 150        35.756468              0.473945
# 151        32.254004              0.882026
# 152        36.336140              0.638878
# 153        35.382149              0.143960
# 154        36.598191              0.477212
# 155        33.848776              0.194850
# 156        36.402910              0.747526
# 157        34.874479              0.075330
# 158        32.242101              0.486452
# 159        36.391954              0.180807
# 160        33.116374              0.917311
# 161        32.093547              0.539134
# 162        34.084039              0.762947
# 163        35.664035              0.706172
# 164        36.009372              0.983082
# 165        35.974166              0.946808
# 166        37.410598              0.355981
# 167        36.457241              0.679967
# 168        33.580240              0.977075
# 169        37.888156              0.182470
# 170        33.553979              0.321395
# 171        32.401833              0.253917
# 172        37.262167              0.228850
# 173        36.161114              0.468291
# 174        36.576346              0.951069
# 175        36.945060              0.102068
# 176        34.833347              0.403889
# 177        34.549093              0.317088
# 178        37.442461              0.791357
# 179        35.944707              0.547631
# 180        32.797770              0.925395
# 181        32.717580              0.406788
# 182        34.819296              0.875514
# 183        32.643945              0.957668
# 184        34.382204              0.313123
# 185        36.257780              0.401554
# 186        32.756741              0.748908
# 187        35.489265              0.484422
# 188        37.209632              0.646705
# 189        32.690161              0.158178
# 190        34.180930              0.111955
# 191        34.507799              0.234593
# 192        37.653316              0.838825
# 193        37.840019              0.339849
# 194        32.354375              0.341406
# 195        32.807778              0.991760
# 196        35.123637              0.586696
# 197        35.487130              0.039881
# 198        34.091889              0.430963
# 199        32.095517              0.764607
# 200        35.194248              0.584981
# 201        35.702480              0.765424
# 202        34.104783              0.034037
# 203        34.491590              0.905631
# 204        32.212663              0.950625
# 205        33.977499              0.635335
# 206        35.976302              0.359131
# 207        37.650536              0.369176
# 208        37.353669              0.225829
# 209        35.447443              0.592103
# 210        32.260053              0.029746
# 211        33.613889              0.859364
# 212        33.432129              0.292318
# 213        32.423068              0.369537
# 214        37.098301              0.241313
# 215        35.475130              0.467018
# 216        37.793026              0.761060
# 217        32.285216              0.896482
# 218        36.036124              0.794140
# 219        35.394813              0.254431
# 220        35.429608              0.419743
# 221        32.802918              0.299516
# 222        32.859509              0.915644
# 223        36.058754              0.745969
# 224        34.909732              0.830674
# 225        37.397101              0.705317
# 226        32.038907              0.738961
# 227        32.138422              0.899959
# 228        37.196374              0.169511
# 229        35.231898              0.448915
# 230        32.831699              0.932589
# 231        33.056528              0.088396
# 232        37.637307              0.459728
# 233        37.100368              0.372364
# 234        34.848662              0.475344
# 235        33.209949              0.703802
# 236        36.151090              0.390872
# 237        36.692895              0.828409
# 238        33.847479              0.579508
# 239        37.722366              0.335114
# 240        32.121515              0.086682
# 241        37.413318              0.612044
# 242        32.938847              0.717109
# 243        37.593528              0.874053
# 244        36.519817              0.199113
# 245        33.677257              0.755765
# 246        35.451635              0.202650
# 247        34.291603              0.524278
# 248        32.647937              0.609509
# 249        37.130105              0.966408
# 250        35.127096              0.658572
# 251        37.398353              0.683962
# 252        34.205128              0.089427
# 253        32.819719              0.302049
# 254        35.097101              0.051155
# 255        37.348864              0.913475
# 256        32.204005              0.765051
# 257        36.274377              0.085973
# 258        37.871622              0.711660
# 259        32.423724              0.591125
# 260        34.599189              0.637937
# 261        37.857076              0.025444
# 262        33.857449              0.213310
# 263        35.388315              0.184708
# 264        33.673155              0.420183
# 265        37.346310              0.311427
# 266        36.463026              0.281206
# 267        33.859834              0.637124
# 268        35.630010              0.781780
# 269        32.089257              0.541229
# 270        34.481961              0.901923
# 271        33.578200              0.539307
# 272        32.742438              0.673056
# 273        36.132461              0.984795
# 274        33.935285              0.593921
# 275        37.329724              0.963204
# 276        33.466953              0.434834
# 277        36.608241              0.733151
# 278        32.340627              0.415414
# 279        33.854562              0.072503
# 280        36.983681              0.531402
# 281        34.246875              0.809655
# 282        32.905144              0.957783
# 283        36.774678              0.806154
# 284        33.024322              0.508845
# 285        37.903481              0.402499
# 286        34.221222              0.197163
# 287        32.663735              0.851411
# 288        33.869749              0.979929
# 289        32.513033              0.026775
# 290        33.636050              0.255392
# 291        37.523408              0.891804
# 292        34.408681              0.127999
# 293        34.773340              0.786043
# 294        32.365542              0.273845
# 295        32.883494              0.286743
# 296        33.314387              0.941194
# 297        36.659455              0.854914
# 298        34.787281              0.796556
# 299        37.945342              0.044893

# %%
data.describe(include='all')
# Out:
#        Región de muestreo Área de muestreo  Sitio de muestreo       Fecha  \
# count                 300              300         300.000000         300
# unique                  1                5                NaN          20
# top             Margarita      La Restinga                NaN  2018-01-15
# freq                  300               60                NaN          15
# mean                  NaN              NaN           2.000000         NaN
# std                   NaN              NaN           0.817861         NaN
# min                   NaN              NaN           1.000000         NaN
# 25%                   NaN              NaN           1.000000         NaN
# 50%                   NaN              NaN           2.000000         NaN
# 75%                   NaN              NaN           3.000000         NaN
# max                   NaN              NaN           3.000000         NaN
#
#        Latitud (° ' '') Longitud (° ' '')  Temperatura (°C)          pH  \
# count               300               300        300.000000  300.000000
# unique               15                15               NaN         NaN
# top        11°1'35.15"N     64°10'53.10"W               NaN         NaN
# freq                 20                20               NaN         NaN
# mean                NaN               NaN         27.463541    8.015115
# std                 NaN               NaN          1.470178    0.582504
# min                 NaN               NaN         25.024395    7.007237
# 25%                 NaN               NaN         26.178524    7.500730
# 50%                 NaN               NaN         27.496035    8.004051
# 75%                 NaN               NaN         28.754298    8.514610
# max                 NaN               NaN         29.969349    8.999610
#
#         Salinidad (PSU)  Clorofila a (mg.m-3)
# count        300.000000            300.000000
# unique              NaN                   NaN
# top                 NaN                   NaN
# freq                NaN                   NaN
# mean          34.909228              0.520460
# std            1.800975              0.285362
# min           32.009921              0.019743
# 25%           33.279384              0.280122
# 50%           34.829284              0.542839
# 75%           36.418267              0.765250
# max           37.956870              0.991760

# %%
área_de_muestreo = data['Área de muestreo']


conteo={'La Restinga': 0,
'Playa el agua': 0,
'Porlamar': 0,
'Punta Arenas': 0,
'Punta de piedras': 0}
for area in área_de_muestreo:
  if area == 'La Restinga':
    conteo['La Restinga'] += 1
  elif area == 'Playa el agua':
    conteo['Playa el agua'] += 1
  elif area == 'Porlamar':
    conteo['Porlamar'] += 1
  elif area == 'Punta Arenas':
    conteo['Punta Arenas'] += 1
  elif area == 'Punta de piedras':
    conteo['Punta de piedras'] += 1


print(conteo)

#conteo = área_de_muestreo.value_counts()
#print(conteo)
# Out:
# {'La Restinga': 60, 'Playa el agua': 60, 'Porlamar': 60, 'Punta Arenas': 60, 'Punta de piedras': 60}

# %%
lon=data["Longitud (° ' '')"][0]
lon[lon.find("'")+1:lon.find('"')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8b7ae411c8c7> in <cell line: 0>()
# ----> 1 lon=data["Longitud (° ' '')"][0]
#       2 lon[lon.find("'")+1:lon.find('"')]
#
# NameError: name 'data' is not defined

# %%
#coordenadas="64°10'53'W"
#latitud_gms=input("introduzca la latitud en formato GMS")
#longitud_gms=input("introduzca la longitud en formato GMS")
latitud_gms='11°1\'35.15"N'
longitud_gms='64°10\'53.10"W'
def GMS_to_GD(latitud_gms,longitud_gms):
  """ Esta funcion toma como dominio de entrada latitud_gms y longitud_gms que son coordendas en formato GMS, luego se segmenta ambos string usando el coomando split
  y se le asigna los valores de grados, minutos y segundos a varias variables y luego transforma las coordanadas a grados decimales y los retorna en las variables
grados1 y grados2"""
  #coordenadas=input("introduzca las cordenas en formato GMS")
  parte1=latitud_gms.split('°')
  parte2=parte1[1].split("'")
  parte3=parte2[1].split('"')
  grados=int(parte1[0])
  minutos=int(parte2[0])
  segundos=float(parte3[0])
  grados_decimales=grados+minutos/60+segundos/3600
  if "W"  in latitud_gms:
    grados_decimales=-grados_decimales
  elif "S" in latitud_gms:
    grados_decimales=-grados_decimales
  parte4=longitud_gms.split('°')
  parte5=parte4[1].split("'")
  parte6=parte5[1].split('"')
  grados2=int(parte4[0])
  minutos2=int(parte5[0])
  segundos2=float(parte6[0])
  grados_decimales2=grados2+minutos2/60+segundos2/3600
  if "W"  in longitud_gms:
    grados_decimales2=-grados_decimales2
  elif "S" in longitud_gms:
    grados_decimales2=-grados_decimales2
  return grados_decimales,grados_decimales2
grados1,grados2=GMS_to_GD(latitud_gms,longitud_gms)
print(grados1,grados2)
print(GMS_to_GD.__doc__)
# Out:
# 11.026430555555557 -64.18141666666668
#  Esta funcion toma como dominio de entrada latitud_gms y longitud_gms que son coordendas en formato GMS, luego se segmenta ambos string usando el coomando split
#   y se le asigna los valores de grados, minutos y segundos a varias variables y luego transforma las coordanadas a grados decimales y los retorna en las variables
# grados1 y grados2

# %%
lat_gms_col="Latitud (° ' '')"
long_gms_col="Longitud (° ' '')"
Lat_g_col="Latitud (°)"
Long_g_col="Longitud (°)"
data=data
#print(data)
def GMS_to_GD_data(data,lat_gms_col,long_gms_col,Lat_g_col,Long_g_col):
    """
    Función para tomar y agragar coordenadas al dataframe.

    Parámetros:
    data: dataframe - dataframe del que se extraen las coordenadas originales y se guardan las coordenadas transformadas.
    lat_gms_col: str - nombre de la columna con los valores de latitud en grados, minutos y segundos
    long_gms_col: str - nombre de la columna con los valores de longitud en grados, minutos y segundos
    Lat_g_col: str - nombre de la nueva columna con valores de latitud en grados decimales
    Long_g_col: str - nombre de la nueva columna con valores de longitud en grados decimales
    """
    for i in range(len(data)):

        latitud_gms, longitud_gms = data[lat_gms_col][i], data[long_gms_col][i]

        data.loc[i,Lat_g_col],data.loc[i,Long_g_col] = GMS_to_GD(latitud_gms,longitud_gms)

    return data

#df = pd.DataFrame(data)
#GMS_to_GD_data(data,lat_gms_col,long_gms_col,Lat_g_col,Long_g_col)
#print(df.head())
#print(df.info())

# %%
df = pd.DataFrame(data)
GMS_to_GD_data(data,lat_gms_col,long_gms_col,Lat_g_col,Long_g_col)
print(df.head())
#print(df.info())
# Out:
#   Región de muestreo Área de muestreo  Sitio de muestreo       Fecha  \
# 0          Margarita      La Restinga                  1  2018-01-15
# 1          Margarita      La Restinga                  2  2018-01-15
# 2          Margarita      La Restinga                  3  2018-01-15
# 3          Margarita    Playa el agua                  1  2018-01-15
# 4          Margarita    Playa el agua                  2  2018-01-15
#
#   Latitud (° ' '') Longitud (° ' '')  Temperatura (°C)        pH  \
# 0     11°1'35.15"N     64°10'53.10"W         28.843873  7.904688
# 1     11°0'52.71"N      64°9'56.76"W         28.072301  7.732033
# 2     11°0'15.78"N      64°8'53.38"W         29.593720  7.488798
# 3     11°10'7.90"N     63°52'41.97"W         25.232745  7.333610
# 4      11°9'9.73"N     63°52'11.46"W         29.559778  8.611946
#
#    Salinidad (PSU)  Clorofila a (mg.m-3)  Latitud (°)  Longitud (°)
# 0        36.288056              0.799730    11.026431    -64.181417
# 1        37.743420              0.777745    11.014642    -64.165767
# 2        34.997775              0.745759    11.004383    -64.148161
# 3        35.663181              0.612321    11.168861    -63.878325
# 4        34.618873              0.580022    11.152703    -63.869850

# %%
data=data
title='Mapa_de_puntos_muestrados'
columna='Área de muestreo'
legend_caption='Área de muestreo'
latmax=11.5
latmin=10.5
lonmax=-63.5
lonmin=-64.5
lat_interval=0.1
lon_interval=0.1
zoom_start=10
#colors =['#ffa51a','red','green','#da50ff','blue']
#colors=['#ffa51a','red','#008000','verde','#0000FF','blue','#FFD700', 'gold','#008000','purple']
colors=['#ffa51a','#008000','#0000FF','#FFD700','#8A2BE2']

def mapa(data,title,columna,legend_caption,latmax,latmin,lonmax,lonmin,lat_interval,lon_interval,zoom_start,colors):
    '''
    Función para crear mapas interactivos.

    Parámetros:

    data: dataframe - Data a utilizar.
    title: str - Título del mapa.
    columna: str - Nombre de la columna según la cual clasificar los datos.
    legend_caption: str - Etiqueta de la leyenda.
    latmax: float - Latitud máxima en grados decimales para la grilla.
    latmin: float - Latitud mínima en grados decimales para la grilla.
    lonmax: float - Longitud máxima en grados decimales para la grilla.
    lonmin: float - Longitud mínima en grados decimales para la grilla.
    lat_interval: float - Intérvalo entre líneas de latitud para la grilla.
    lon_interval: float - Intérvalo entre líneas de longitud para la grilla.
    zoom_start: float - Zoom inicial.
    colors: lista - Lista de colores.
    '''
    #Creamos el mapa. Aplicamos el método explore de geopandas para crear el mapa.

    lat=(latmax-latmin)/2+latmin
    lon=(lonmax-lonmin)/2+lonmin

    m=folium.Map(min_lon=lonmin,
                 max_lon=lonmax,
                 min_lat=latmin,
                 max_lat=latmax,
                 location=[lat, lon],
                 max_bounds=False,
                 min_zoom=7,
                 zoom_start=zoom_start,
                 zoom_control=False,
                 control_scale=True)

    #Tiles. Estas son las ´capas´ o 'mosaicos' que componen el mapa y que podemos ver de acuerdo a nuestra elección y al nivel de zoom.
    #Aquí colocamos tres tiles aparte de la que viene por defecto (openstreetmap).

    tile = folium.TileLayer(tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                            attr = 'Esri',
                            name = 'Esri Satellite',
                            overlay = False,
                            control = True,
                            ).add_to(m)

    tile = folium.TileLayer(tiles = 'https://{s}.basemaps.cartocdn.com/rastertiles/voyager_nolabels/{z}/{x}/{y}{r}.png',
                            attr = '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>',
                            name = 'CartoDB.VoyagerNoLabels',
                            overlay = False,
                            control = True,
                            min_zoom=7,
                            max_zoom=20).add_to(m)


    tile = folium.TileLayer(tiles = 'http://{s}.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
                            name = 'Google',
                            attr= 'ThanksToGoogleMap',
                            subdomains=['mt0','mt1','mt2','mt3'],
                            overlay = False,
                            control = True,
                            max_zoom=20).add_to(m)


    #Posición del mouse
    plugins.MousePosition().add_to(m)



    #Título

    #Características del título
    title_html = """<h1 aling = "center", style="font-family: verdana; font-size:16px;font-weight:bold; background-color: black; color: white; padding:10px; text-transform: uppercase;">{}</h1>""".format(title)

    m.get_root().html.add_child(folium.Element(title_html))


    #Agregando markers al mapa

    claves=data[columna].unique()
    colore=dict(zip(claves,colors))

    for i in data.index:
        popup=data['Área de muestreo'][i] + ', Sitio: ' + str(data['Sitio de muestreo'][i])

        folium.CircleMarker([data['Latitud (°)'][i], data['Longitud (°)'][i]],
                            radius=10,
                            fill=True,
                            fill_opacity= 0.7,
                            fill_color=colore[data[columna][i]],
                            color='black',
                            popup=folium.Popup(popup,max_width=200)).add_to(m)




    #Grilla
    attr = {'fill': 'white', 'font-weight': 'bold', 'font-size': '20','stroke':"black"}


    for lon in np.arange(lonmin, lonmax+0.0001, lon_interval):
        line=folium.PolyLine([[latmin, lon],[latmax, lon]], weight=1, tooltip=str(round(lon,5)), color='white')
        wind_textpath = plugins.PolyLineTextPath(line,
                                                 str(round(lon,5)),
                                                 below=True,
                                                 offset=-5,
                                                 attributes=attr)
        m.add_child(line)
        m.add_child(wind_textpath)

    for lat in np.arange(latmin, latmax+0.0001, lat_interval):
        line=folium.PolyLine([[lat, lonmin],[lat, lonmax]], weight=1, tooltip=str(round(lat,5)),color='white')
        wind_textpath = plugins.PolyLineTextPath(line,
                                                 str(round(lat,5)),
                                                 below=True,
                                                 offset=-5,
                                                 attributes=attr)
        m.add_child(line)
        m.add_child(wind_textpath)


    #Legenda

    items=list()
    item_txt = """<br> &nbsp; <i class="fas fa-circle fas-2x" style="color:{col}; border: 2px solid black; border-radius: 50%; padding: 0px"></i> {item}"""
    serie=data[columna].drop_duplicates(keep='last').sort_values()
    for i in range(len(serie)):
        globals()['html_itms_'+serie.iloc[i].replace(' ','_')] = item_txt.format( item= serie.iloc[i] , col= colore[serie.iloc[i]])
        items.append(globals()['html_itms_'+serie.iloc[i].replace(' ','_')])

    font_size=30

    width=(serie.str.len().max()+2)*2*font_size/3
    height=(len(serie)+1)*8*font_size/5

    legend_html = '<div style="width:'+str(width)+'px; height:'+str(height)+'px; border:2px solid grey; z-index:9999; background-color:white; opacity: .85; font-size:'+str(font_size)+'px; font-weight: bold;"> &nbsp;'
    legend_html= legend_html + legend_caption

    for i in items:
        legend_html= legend_html +i
    legend_html= legend_html + "</div>"

    legend_html.format( title = 'legend_caption')

    folium.map.Marker([latmin + (latmax-latmin)/2, lonmax+0.05*(lonmax-lonmin)],
                      draggable=True,
                      icon=folium.features.DivIcon(icon_size=(width,height),
                                   icon_anchor=(0,0),
                                   html=legend_html)).add_to(m)



    #Norte

    url = ("https://github.com/AndresEdSu/Mapas/blob/main/Norte%20DEF.png?raw=true")
    folium.map.Marker([latmax -  0.1*(latmax-latmin), lonmax-0.1*(lonmax-lonmin)],
                      draggable=True,
                      icon=folium.features.CustomIcon(icon_image=url,
                                                      icon_size=(1.5*70,1.5*90),
                                                      icon_anchor=(50,50))).add_to(m)


    #Minimapa
    mmap1=plugins.MiniMap(position='topleft',width=300, height=450,zoom_level_offset=-5,toggle_display=True)
    mmap1.add_to(m)



    #Layercontrol
    folium.LayerControl().add_to(m)

    #Guardar mapa
    m.save(title+'.html')

    return m

mapa(data,title,columna,legend_caption,latmax,latmin,lonmax,lonmin,lat_interval,lon_interval,zoom_start,colors)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25b60f247977ff5188f7bdc56c387d5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-textpath@1.2.3/leaflet.textpath.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h1 aling = &quot;center&quot;, style=&quot;font-family: verdana; font-size:16px;font-weight:bold; background-color: black; color: white; padding:10px; text-transform: uppercase;&quot;&gt;Mapa_de_puntos_muestrados&lt;/h1&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25b60f247977ff5188f7bdc56c387d5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25b60f247977ff5188f7bdc56c387d5b = L.map(
#                 &quot;map_25b60f247977ff5188f7bdc56c387d5b&quot;,
#                 {
#                     center: [11.0, -64.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: false,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_25b60f247977ff5188f7bdc56c387d5b);
#
#
#
#
#
#             var tile_layer_18f6e731b2db8d0ad96ff298f4927f1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 7,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18f6e731b2db8d0ad96ff298f4927f1d.addTo(map_25b60f247977ff5188f7bdc56c387d5b);
#
#
#             var tile_layer_ddae7c4cb098a248821fd87850b93495 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Esri&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ddae7c4cb098a248821fd87850b93495.addTo(map_25b60f247977ff5188f7bdc56c387d5b);
#
#
#             var tile_layer_1b054f3219ca4d2657ff1fdafbaca284 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/rastertiles/voyager_nolabels/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 7,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b054f3219ca4d2657ff1fdafbaca284.addTo(map_25b60f247977ff5188f7bdc56c387d5b);
#
#
#             var tile_layer_4fd2e8bba40ba8fa2b72408bf5ed0fd6 = L.tileLayer(
#                 &quot;http://{s}.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;ThanksToGoogleMap&quot;,
#   &quot;subdomains&quot;: [
# &quot;mt0&quot;,
# &quot;mt1&quot;,
# &quot;mt2&quot;,
# &quot;mt3&quot;,
# ],
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4fd2e8bba40ba8fa2b72408bf5ed0fd6.addTo(map_25b60f247977ff5188f7bdc56c387d5b);
#
#
#             var mouse_position_1a53f94e3f5ccc090045a22bf76c66c8 = new L.Control.MousePosition(
#                 {
#   &quot;position&quot;: &quot;bottomright&quot;,
#   &quot;separator&quot;: &quot; : &quot;,
#   &quot;emptyString&quot;: &quot;Unavailable&quot;,
#   &quot;lngFirst&quot;: false,
#   &quot;numDigits&quot;: 5,
#   &quot;prefix&quot;: &quot;&quot;,
# }
#             );
#             mouse_position_1a53f94e3f5ccc090045a22bf76c66c8.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_1a53f94e3f5ccc090045a22bf76c66c8.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_25b60f247977ff5188f7bdc56c387d5b.addControl(mouse_position_1a53f94e3f5ccc090045a22bf76c66c8);
#
#
#             var circle_marker_479f98ec7cae37c7a132474434a6066c = L.circleMarker(
#                 [11.026430555555557, -64.18141666666668],
#                 {&quot;bubblingMouseEvent

# %%
data_mean=data.copy()

data_mean=data_mean.groupby(['Área de muestreo','Fecha'])[['Temperatura (°C)', 'pH', 'Salinidad (PSU)', 'Clorofila a (mg.m-3)']].mean()

data_mean
# Out:
#                              Temperatura (°C)        pH  Salinidad (PSU)  \
# Área de muestreo Fecha
# La Restinga      2018-01-15         28.836631  7.708506        36.343084
#                  2018-04-15         27.290460  8.556773        35.236912
#                  2018-07-15         26.924365  7.806075        35.501846
#                  2018-10-15         28.228930  8.432923        35.084744
#                  2019-01-15         26.821301  8.252422        35.737035
#                  2019-04-15         28.175705  8.078311        34.823602
#                  2019-07-15         27.010782  7.886146        33.987717
#                  2019-10-15         26.887914  8.486356        36.621851
#                  2020-01-15         27.375183  8.102042        35.995726
#                  2020-04-15         26.506012  7.946547        32.423910
#                  2020-07-15         27.897990  7.937613        34.782204
#                  2020-10-15         28.219295  7.819566        36.614002
#                  2021-01-15         26.930550  8.042160        33.444882
#                  2021-04-15         28.298754  8.197247        34.472848
#                  2021-07-15         26.007326  8.507295        33.102024
#                  2021-10-15         26.786870  8.482296        33.858143
#                  2022-01-15         26.043327  8.723050        34.157893
#                  2022-04-15         27.841964  7.787762        35.275749
#                  2022-07-15         28.482892  8.045062        33.600866
#                  2022-10-15         27.525079  8.043964        34.929479
# Playa el agua    2018-01-15         28.110286  8.047991        34.097817
#                  2018-04-15         28.039392  8.557767        34.884361
#                  2018-07-15         28.432300  8.544009        35.277318
#                  2018-10-15         27.268584  7.842335        34.162329
#                  2019-01-15         27.632495  7.927880        36.394954
#                  2019-04-15         27.405121  8.072372        34.716761
#                  2019-07-15         27.648103  7.818888        35.643671
#                  2019-10-15         26.935319  8.559048        34.685834
#                  2020-01-15         27.977007  8.014309        35.217621
#                  2020-04-15         27.042381  8.536146        34.537869
#                  2020-07-15         27.707742  8.305433        35.276372
#                  2020-10-15         27.539547  7.212086        35.007458
#                  2021-01-15         26.790911  7.980145        34.427976
#                  2021-04-15         27.647136  7.360896        33.793885
#                  2021-07-15         28.525100  8.331281        34.998833
#                  2021-10-15         27.047565  8.066014        35.086657
#                  2022-01-15         26.074481  7.270386        35.930201
#                  2022-04-15         27.033241  7.781144        34.964845
#                  2022-07-15         27.268050  7.330106        35.799157
#                  2022-10-15         28.717645  7.671952        33.339611
# Porlamar         2018-01-15         26.866515  7.899992        33.011339
#                  2018-04-15         26.776203  7.763162        35.320371
#                  2018-07-15         27.160100  8.824905        33.638358
#                  2018-10-15         25.991215  8.401463        34.531054
#                  2019-01-15         27.993622  7.987283        36.810254
#                  2019-04-15         27.846330  8.495294        33.326564
#                  2019-07-15         27.236834  8.293129        33.293591
#                  2019-10-15         27.699079  8.019571        35.853827
#                  2020-01-15         28.472771  8.055952        34.333553
#                  2020-04-15         26.451535  7.777813        33.908809
#                  2020-07-15         25.842016  8.078452        34.506497
#                  2020-10-15         27.327616  7.678763        35.275038
#                  2021-01-15         27.355533  8.035388        35.151879
#                  2021-04-15         26.293926  8.093078        34.766284
#                  2021-07-15         26.932354  7.326872        35.371455
#                  2021-10-15         28.571942  7.360389        35.931401
#                  2022-01-15         26.211868  7.845140        34.130392
#                  2022-04-15         28.814410  8.064692        35.700947
#                  2022-07-15         27.439890  8.148757        34.138607
#                  2022-10-15         26.291244  8.633803        35.568476
# Punta Arenas     2018-01-15         28.072183  8.595323        35.314491
#                  2018-04-15         27.655004  7.712773        35.532152
#                  2018-07-15         27.530680  8.811697        35.829102
#                  2018-10-15         28.014032  7.871015        34.973858
#                  2019-01-15         27.860954  7.883451        34.062350
#                  2019-04-15         26.333771  7.794789        35.652533
#                  2019-07-15         27.910004  7.775242        36.567888
#                  2019-10-15         26.612151  7.936674        34.372526
#                  2020-01-15         26.240695  7.528645        35.335371
#                  2020-04-15         28.510694  7.882345        35.683747
#                  2020-07-15         28.284730  8.112288        33.867292
#                  2020-10-15         28.718228  8.308667        36.118251
#                  2021-01-15         26.517048  8.218321        33.792963
#                  2021-04-15         28.309405  7.484878        34.055488
#                  2021-07-15         27.720597  7.760152        34.542446
#                  2021-10-15         28.734190  8.086412        34.736567
#                  2022-01-15         26.660720  7.801934        36.551851
#                  2022-04-15         28.495243  8.424753        35.827497
#                  2022-07-15         28.758219  8.062325        35.028373
#                  2022-10-15         26.960168  7.676813        32.854474
# Punta de piedras 2018-01-15         28.938500  7.937001        33.494266
#                  2018-04-15         28.853522  7.503705        35.153378
#                  2018-07-15         26.983004  7.161077        34.710035
#                  2018-10-15         26.615063  7.694006        33.895146
#                  2019-01-15         28.595924  7.938947        36.121614
#                  2019-04-15         25.533122  8.340623        34.951651
#                  2019-07-15         28.063041  8.143672        32.791825
#                  2019-10-15         27.606441  8.242200        36.897145
#                  2020-01-15         27.250297  8.384263        35.640973
#                  2020-04-15         26.891033  8.336336        34.467076
#                  2020-07-15         27.683716  7.913893        35.252482
#                  2020-10-15         27.954015  7.615804        35.978754
#                  2021-01-15         27.404613  7.932197        35.949237
#                  2021-04-15         26.589269  8.535023        36.817216
#                  2021-07-15         28.082600  7.494547        34.609331
#                  2021-10-15         27.165707  8.225620        36.087580
#                  2022-01-15         29.080407  8.321743        34.040649
#                  2022-04-15         27.002237  7.703260        33.859700
#                  2022-07-15         25.926057  7.757152        34.234714
#                  2022-10-15         27.728104  7.745708        36.464026
#
#                              Clorofila a (mg.m-3)
# Área de muestreo Fecha
# La Restinga      2018-01-15              0.774411
#                  2018-04-15              0.245901
#                  2018-07-15              0.578944
#                  2018-10-15              0.552876
#                  2019-01-15              0.363861
#                  2019-04-15              0.504051
#                  2019-07-15              0.698861
#                  2019-10-15              0.733533
#                  2020-01-15              0.471515
#                  2020-04-15              0.191691
#                  2020-07-15              0.664949
#                  2020-10-15              0.660918
#                  2021-01-15              0.735899
#                  2021-04-15              0.539446
#                  2021-07-15              0.393809
#                  2021-10-15              0.781412
#                  2022-01-15              0.471945
#                  2022-04-15              0.588166
#                  2022-07-15              0.704762
#                  2022-10-15              0.483691
# Playa el agua    2018-01-15              0.492016
#                  2018-04-15              0.659121
#                  2018-07-15              0.517857
#                  2018-10-15              0.421099
#                  2019-01-15              0.386708
#                  2019-04-15              0.400277
#                  2019-07-15              0.278695
#                  2019-10-15              0.386850
#                  2020-01-15              0.725454
#                  2020-04-15              0.589545
#                  2020-07-15              0.272007
#                  2020-10-15              0.493647
#                  2021-01-15              0.557448
#                  2021-04-15              0.593517
#                  2021-07-15              0.359290
#                  2021-10-15              0.517005
#                  2022-01-15              0.609644
#                  2022-04-15              0.646907
#                  2022-07-15              0.847306
#                  2022-10-15              0.420699
# Porlamar         2018-01-15              0.638124
#                  2018-04-15              0.567428
#                  2018-07-15              0.440768
#                  2018-10-15              0.658848
#                  2019-01-15              0.607164
#                  2019-04-15              0.387665
#                  2019-07-15              0.680299
#                  2019-10-15              0.575588
#                  2020-01-15              0.711175
#                  2020-04-15              0.257506
#                  2020-07-15              0.436436
#                  2020-10-15              0.317020
#                  2021-01-15              0.626679
#                  2021-04-15              0.568364
#                  2021-07-15              0.817228
#                  2021-10-15              0.306829
#                  2022-01-15              0.445479
#                  2022-04-15              0.141154
#                  2022-07-15              0.527800
#                  2022-10-15              0.601948
# Punta Arenas     2018-01-15              0.409631
#                  2018-04-15              0.564273
#                  2018-07-15              0.390384
#                  2018-10-15              0.164478
#                  2019-01-15              0.545113
#                  2019-04-15              0.734453
#                  2019-07-15              0.192882
#                  2019-10-15              0.444454
#                  2020-01-15              0.363923
#                  2020-04-15              0.454112
#                  2020-07-15              0.545751
#                  2020-10-15              0.485675
#                  2021-01-15              0.168242
#                  2021-04-15              0.648364
#                  2021-07-15              0.324563
#                  2021-10-15              0.523339
#                  2022-01-15              0.769647
#                  2022-04-15              0.337605
#                  2022-07-15              0.471187
#                  2022-10-15              0.500594
# Punta de piedras 2018-01-15              0.603324
#                  2018-04-15              0.387656
#                  2018-07-15              0.286079
#                  2018-10-15              0.681088
#                  2019-01-15              0.560303
#                  2019-04-15              0.658872
#                  2019-07-15              0.705434
#                  2019-10-15              0.375030
#                  2020-01-15              0.701561
#                  2020-04-15              0.611142
#                  2020-07-15              0.817400
#                  2020-10-15              0.552025
#                  2021-01-15              0.506693
#                  2021-04-15              0.395703
#                  2021-07-15              0.830762
#                  2021-10-15              0.581010
#                  2022-01-15              0.147544
#                  2022-04-15              0.653378
#                  2022-07-15              0.757594
#                  2022-10-15              0.565454

# %%
dt=data_mean
variable='Temperatura (°C)'
title='Serie Temporal de temperatura'
colors=['#ffa51a','#008000','#0000FF','#FFD700','#8A2BE2']
# Obtener los valores únicos de la columna "Área de muestreo"
areas_de_muestreo = dt.index.get_level_values("Área de muestreo").unique()
colore = dict(zip(areas_de_muestreo, colors))
print(colore)
def serie_temporal(dt,variable,title,colors):
    '''
    Función realizar serie de tiempo.

    Parámetros:

    dt: dataframe - Data a utilizar.
    variable: str - Nombre de la columna con los datos de la variable de interés.
    title: str - Título del gráfico.
    colors: dict - Diccionario de colores por área de muestreo
    '''
    #Creamos la figura y asignamos dimensiones
    plt.figure(figsize=(15,6))


    #Realizamos las series de tiempo
    for area in data_mean.index.get_level_values("Área de muestreo").unique():
          plt.plot(dt[variable][area].index, dt[variable][area], label=area,color=colore[area])


    # Etiquetamos los ejes
    plt.xlabel('Fecha', fontsize=15)
    plt.ylabel(variable, fontsize=15)

    #Rotamos los valores del eje x
    plt.xticks(rotation=45, ha='right')

    #Colocamos la leyenda y la ubicamos convenientemente
    plt.legend(loc=(1,0))

    #Colocamos el título
    plt.title(title,fontsize=20)

    #Esto es para guardar la imagen
    plt.savefig(title+'.jpg', bbox_inches='tight')

    plt.show
serie_temporal(dt,variable,title,colors)
# Out:
# {'La Restinga': '#ffa51a', 'Playa el agua': '#008000', 'Porlamar': '#0000FF', 'Punta Arenas': '#FFD700', 'Punta de piedras': '#8A2BE2'}

# %%
variables = ['Temperatura (°C)', 'pH', 'Salinidad (PSU)', 'Clorofila a (mg.m-3)']
for variable in variables:
  title = f'Serie Temporal de {variable}'
  serie_temporal(dt, variable, title, colore)

# %%
# !ls /content
# Out:
# drive				       Proyecto_Pyhon_Carlos_Castillo.ipynb
# Proyecto-geolocalizaci-n-de-muestras-  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/Proyecto-geolocalizaci-n-de-muestras-
# Out:
# /content/Proyecto-geolocalizaci-n-de-muestras-

# %%
# !ls
# Out:
# Proyecto_Pyhon_Carlos_Castillo.ipynb

# %%
# !git add .

# %%
# !git config --global user.email "carloseduardo_2527@hotmail.com"
# !git config --global user.name "carliol89"

# %%
# !git checkout -b main
# Out:
# Switched to a new branch 'main'

# %%
# !git add .
# !git commit -m "Creando la rama main y subiendo proyecto"
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --list
# Out:
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# filter.lfs.clean=git-lfs clean -- %f
# user.email=carloseduardo_2527@hotmail.com
# user.name=carliol89
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://github.com/carliol89/Proyecto-geolocalizaci-n-de-muestras-.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*

# %%
# !git status
# Out:
# On branch main
# nothing to commit, working tree clean
